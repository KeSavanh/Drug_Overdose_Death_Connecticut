# %%
import pandas as pd
import os
from sqlalchemy import create_engine
from config import pwd
import psycopg2

# %%
#Extract csv into dataframe
CTdrug_overdose_csv = "Accidental_Drug_Related_Deaths_2012-2020.csv"
drug_df = pd.read_csv(CTdrug_overdose_csv)
drug_df.head()
# Out:
#         ID        Date    Date Type   Age     Sex   Race Residence City  \
# 0  12-0187  07/17/2012  DateofDeath  34.0  Female  White        MAHOPAC
# 1  12-0258  10/01/2012  DateofDeath  51.0    Male  White       PORTLAND
# 2  13-0146  04/28/2013  DateofDeath  28.0    Male  White            NaN
# 3  14-0150  04/06/2014  DateofDeath  46.0    Male  White      WATERBURY
# 4  14-0183  04/27/2014  DateofDeath  52.0    Male  White     NEW LONDON
#
#   Residence County Residence State  Death City  ... Morphine (Not Heroin)  \
# 0           PUTNAM             NaN     DANBURY  ...                   NaN
# 1        MIDDLESEX             NaN    PORTLAND  ...                   NaN
# 2              NaN             NaN    HARTFORD  ...                   NaN
# 3              NaN             NaN  TORRINGTON  ...                   NaN
# 4              NaN             NaN  NEW LONDON  ...                   NaN
#
#   Hydromorphone Xylazine   Other Opiate NOS Any Opioid Manner of Death  \
# 0           NaN      NaN  Duster        NaN        NaN        Accident
# 1           NaN      NaN     NaN        NaN        NaN        Accident
# 2           NaN      NaN     NaN        NaN        NaN        Accident
# 3           NaN      NaN     NaN        NaN        NaN        Accident
# 4           NaN      NaN     NaN        NaN        NaN        Accident
#
#                               DeathCityGeo  \
# 0     DANBURY, CT\n(41.393666, -73.451539)
# 1    PORTLAND, CT\n(41.581345, -72.634112)
# 2    HARTFORD, CT\n(41.765775, -72.673356)
# 3  TORRINGTON, CT\n(41.812186, -73.101552)
# 4  NEW LONDON, CT\n(41.355167, -72.099561)
#
#                           ResidenceCityGeo                InjuryCityGeo
# 0                                      NaN  CT\n(41.575155, -72.738288)
# 1    PORTLAND, CT\n(41.581345, -72.634112)  CT\n(41.575155, -72.738288)
# 2              CT\n(41.575155, -72.738288)  CT\n(41.575155, -72.738288)
# 3   WATERBURY, CT\n(41.554261, -73.043069)  CT\n(41.575155, -72.738288)
# 4  NEW LONDON, CT\n(41.355167, -72.099561)  CT\n(41.575155, -72.738288)
#
# [5 rows x 42 columns]

# %%
#Create dataframe for specific columns
drug_df[['City','state','Lat']] = drug_df['ResidenceCityGeo'].str.split(',',expand=True)

drug_df[['state','Lat']] = drug_df['state'].str.split('\n',expand=True)
drug_df
# Out:
#            ID        Date    Date Type   Age     Sex   Race Residence City  \
# 0     12-0187  07/17/2012  DateofDeath  34.0  Female  White        MAHOPAC
# 1     12-0258  10/01/2012  DateofDeath  51.0    Male  White       PORTLAND
# 2     13-0146  04/28/2013  DateofDeath  28.0    Male  White            NaN
# 3     14-0150  04/06/2014  DateofDeath  46.0    Male  White      WATERBURY
# 4     14-0183  04/27/2014  DateofDeath  52.0    Male  White     NEW LONDON
# ...       ...         ...          ...   ...     ...    ...            ...
# 7674  14-0128  03/20/2014  DateofDeath  25.0    Male  White        MILFORD
# 7675  20-1217  11/19/2020  DateofDeath  62.0  Female  White       STAMFORD
# 7676  20-1138  10/31/2020  DateofDeath  50.0  Female  White    NEW BRITAIN
# 7677  16-0640  09/17/2016  DateofDeath  36.0    Male  White        SHELTON
# 7678  19-0963  10/25/2019  DateofDeath  33.0    Male  White      NEW HAVEN
#
#      Residence County Residence State    Death City  ...   Other Opiate NOS  \
# 0              PUTNAM             NaN       DANBURY  ...  Duster        NaN
# 1           MIDDLESEX             NaN      PORTLAND  ...     NaN        NaN
# 2                 NaN             NaN      HARTFORD  ...     NaN        NaN
# 3                 NaN             NaN    TORRINGTON  ...     NaN        NaN
# 4                 NaN             NaN    NEW LONDON  ...     NaN        NaN
# ...               ...             ...           ...  ...     ...        ...
# 7674              NaN             NaN  WETHERSFIELD  ...     NaN        NaN
# 7675        FAIRFIELD              CT      STAMFORD  ...     NaN        NaN
# 7676         HARTFORD              CT   NEW BRITAIN  ...     NaN        NaN
# 7677        FAIRFIELD              CT       SHELTON  ...     NaN        NaN
# 7678        NEW HAVEN              CT     NEW HAVEN  ...     NaN        NaN
#
#      Any Opioid Manner of Death                               DeathCityGeo  \
# 0           NaN        Accident       DANBURY, CT\n(41.393666, -73.451539)
# 1           NaN        Accident      PORTLAND, CT\n(41.581345, -72.634112)
# 2           NaN        Accident      HARTFORD, CT\n(41.765775, -72.673356)
# 3           NaN        Accident    TORRINGTON, CT\n(41.812186, -73.101552)
# 4           NaN        Accident    NEW LONDON, CT\n(41.355167, -72.099561)
# ...         ...             ...                                        ...
# 7674        NaN        Accident  WETHERSFIELD, CT\n(41.712487, -72.663607)
# 7675          Y        Accident      Stamford, CT\n(41.051924, -73.539475)
# 7676          Y        Accident   New Britain, CT\n(41.667528, -72.783437)
# 7677          Y        Accident       SHELTON, CT\n(41.316843, -73.092968)
# 7678          Y        Accident     New Haven, CT\n(41.308252, -72.924161)
#
#                               ResidenceCityGeo  \
# 0                                          NaN
# 1        PORTLAND, CT\n(41.581345, -72.634112)
# 2                  CT\n(41.575155, -72.738288)
# 3       WATERBURY, CT\n(41.554261, -73.043069)
# 4      NEW LONDON, CT\n(41.355167, -72.099561)
# ...                                        ...
# 7674      MILFORD, CT\n(41.224276, -73.057564)
# 7675     STAMFORD, CT\n(41.051924, -73.539475)
# 7676  NEW BRITAIN, CT\n(41.667528, -72.783437)
# 7677      SHELTON, CT\n(41.316843, -73.092968)
# 7678    NEW HAVEN, CT\n(41.308252, -72.924161)
#
#                                  InjuryCityGeo            City         state  \
# 0                  CT\n(41.575155, -72.738288)             NaN           NaN
# 1                  CT\n(41.575155, -72.738288)        PORTLAND            CT
# 2                  CT\n(41.575155, -72.738288)  CT\n(41.575155   -72.738288)
# 3                  CT\n(41.575155, -72.738288)       WATERBURY            CT
# 4                  CT\n(41.575155, -72.738288)      NEW LONDON            CT
# ...                                        ...             ...           ...
# 7674               CT\n(41.575155, -72.738288)         MILFORD            CT
# 7675     STAMFORD, CT\n(41.051924, -73.539475)        STAMFORD            CT
# 7676  NEW BRITAIN, CT\n(41.667528, -72.783437)     NEW BRITAIN            CT
# 7677      SHELTON, CT\n(41.316843, -73.092968)         SHELTON            CT
# 7678    NEW HAVEN, CT\n(41.308252, -72.924161)       NEW HAVEN            CT
#
#              Lat
# 0            NaN
# 1     (41.581345
# 2           None
# 3     (41.554261
# 4     (41.355167
# ...          ...
# 7674  (41.224276
# 7675  (41.051924
# 7676  (41.667528
# 7677  (41.316843
# 7678  (41.308252
#
# [7679 rows x 45 columns]

# %%
drug_cols = ['ID','Date','Sex','Race','Cause of Death','City','state']
drug_transformed = drug_df[drug_cols].copy()

drug_transformed.head(20)


drug_transformed = drug_transformed.replace('\n','',regex=True)
drug_transformed.head()
# Out:
#         ID        Date     Sex   Race                   Cause of Death  \
# 0  12-0187  07/17/2012  Female  White      1,1-Difluoroethane Toxicity
# 1  12-0258  10/01/2012    Male  White                  Heroin Toxicity
# 2  13-0146  04/28/2013    Male  White            Acute Heroin Toxicity
# 3  14-0150  04/06/2014    Male  White  Heroin and Cocaine Intoxication
# 4  14-0183  04/27/2014    Male  White        Acute Heroin Intoxication
#
#            City         state
# 0           NaN           NaN
# 1      PORTLAND            CT
# 2  CT(41.575155   -72.738288)
# 3     WATERBURY            CT
# 4    NEW LONDON            CT

# %%
newdrug_df = drug_transformed[~drug_transformed['City'].fillna('').str.findall(r'\d').astype(bool)]
newdrug_df.head()
# Out:
#         ID        Date     Sex   Race                   Cause of Death  \
# 0  12-0187  07/17/2012  Female  White      1,1-Difluoroethane Toxicity
# 1  12-0258  10/01/2012    Male  White                  Heroin Toxicity
# 3  14-0150  04/06/2014    Male  White  Heroin and Cocaine Intoxication
# 4  14-0183  04/27/2014    Male  White        Acute Heroin Intoxication
# 5  15-0023  01/12/2015    Male  White           Acute Cocaine Toxicity
#
#          City state
# 0         NaN   NaN
# 1    PORTLAND    CT
# 3   WATERBURY    CT
# 4  NEW LONDON    CT
# 5  NEW LONDON    CT

# %%
newdrug_df.dropna(how = 'any',inplace=True)
newdrug_df
# Out:
# <ipython-input-34-5cd6752a31f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdrug_df.dropna(how = 'any',inplace=True)
#            ID        Date     Sex   Race  \
# 1     12-0258  10/01/2012    Male  White
# 3     14-0150  04/06/2014    Male  White
# 4     14-0183  04/27/2014    Male  White
# 5     15-0023  01/12/2015    Male  White
# 6     15-0052  02/01/2015    Male  White
# ...       ...         ...     ...    ...
# 7674  14-0128  03/20/2014    Male  White
# 7675  20-1217  11/19/2020  Female  White
# 7676  20-1138  10/31/2020  Female  White
# 7677  16-0640  09/17/2016    Male  White
# 7678  19-0963  10/25/2019    Male  White
#
#                                          Cause of Death         City state
# 1                                       Heroin Toxicity     PORTLAND    CT
# 3                       Heroin and Cocaine Intoxication    WATERBURY    CT
# 4                             Acute Heroin Intoxication   NEW LONDON    CT
# 5                                Acute Cocaine Toxicity   NEW LONDON    CT
# 6                                 Acute Heroin Toxicity   MIDDLETOWN    CT
# ...                                                 ...          ...   ...
# 7674                                Heroin Intoxication      MILFORD    CT
# 7675  Multidrug Toxicity Including Cocaine, Fentanyl...     STAMFORD    CT
# 7676  Acute Intoxication Due To The Combined Effects...  NEW BRITAIN    CT
# 7677  Acute Intoxication The Combined Effects of Her...      SHELTON    CT
# 7678  Pulmonary Embolus Complicating Lower Extremity...    NEW HAVEN    CT
#
# [7204 rows x 7 columns]

# %%
newdrug_df.set_index("ID",inplace=True)
newdrug_df.head()
# Out:
#                Date   Sex   Race                   Cause of Death        City  \
# ID
# 12-0258  10/01/2012  Male  White                  Heroin Toxicity    PORTLAND
# 14-0150  04/06/2014  Male  White  Heroin and Cocaine Intoxication   WATERBURY
# 14-0183  04/27/2014  Male  White        Acute Heroin Intoxication  NEW LONDON
# 15-0023  01/12/2015  Male  White           Acute Cocaine Toxicity  NEW LONDON
# 15-0052  02/01/2015  Male  White            Acute Heroin Toxicity  MIDDLETOWN
#
#         state
# ID
# 12-0258    CT
# 14-0150    CT
# 14-0183    CT
# 15-0023    CT
# 15-0052    CT

# %%
#Connecting to database

engine = create_engine(f'postgresql+psycopg2://postgres:{pwd}@localhost:5432/drug_db')
conn=engine.connect()

# %%
engine.table_names()
# Out:
# <ipython-input-48-d72bc75a6b62>:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['drugOverdose', 'drugoverdose']

# %%
newdrug_df.to_sql(name='drugoverdose',con=engine,if_exists='append',index=False)
